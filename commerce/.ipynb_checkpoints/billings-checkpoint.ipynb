# %%
import pandas as pd
import numpy as np
name = "billing_and_accruals_for_script_2025-09-01_09-14-43"

# %%
pip install --upgrade openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/boris/myenv/lib/python3.12/site-packages (3.0.7)
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: et-xmlfile in /home/boris/myenv/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Installing collected packages: openpyxl
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.0.7
#     Uninstalling openpyxl-3.0.7:
#       Successfully uninstalled openpyxl-3.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gosuslugi-api 0.7.0 requires openpyxl==3.0.7, but you have openpyxl 3.1.5 which is incompatible.
# gosuslugi-api 0.7.0 requires requests==2.25.1, but you have requests 2.32.5 which is incompatible.
# Successfully installed openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
dtype_dict = {
    'КПП': str,
}
dataset = pd.read_excel('/home/boris/Downloads/' + name + '.xlsx', dtype=dtype_dict)
dataset['КПП'] = dataset['КПП'].astype(str)
dataset['Начисления partner'] = dataset['Начисления partner'].fillna(0)
dataset['Сумма-test'] = dataset['Сумма']

# %%
dataset = dataset.sort_values(by=['Название компании', 'Дата', 'Название номенклатуры '])
dataset
# Out:
#               Название компании       Дата  Личный кабинет  \
# 12401  "Виконт"  ИП Зайцев В.А. 2025-07-31        131415.0
# 12402  "Виконт"  ИП Зайцев В.А. 2025-08-31        131415.0
# 12403  "Виконт"  ИП Зайцев В.А. 2025-09-30        131415.0
# 16652                         1 2025-01-31        155522.0
# 16653                         1 2025-02-28        155522.0
# ...                         ...        ...             ...
# 9613                        NaN 2025-09-30        123862.0
# 10037                       NaN 2025-09-30        124209.0
# 10164                       NaN 2025-09-30        124229.0
# 11005                       NaN 2025-09-30        125060.0
# 12500                       NaN 2025-09-30        131611.0
#
#                            ЛС           ИНН        КПП  \
# 12401                     NaN  583600200160        nan
# 12402                     NaN  583600200160        nan
# 12403                     NaN  583600200160        nan
# 16652  Подписка ПРО ЛК 155522             1  ФФФФФФФФФ
# 16653  Подписка ПРО ЛК 155522             1  ФФФФФФФФФ
# ...                       ...           ...        ...
# 9613                      NaN    5408028562  540801001
# 10037                     NaN    7415008049  741501001
# 10164                     NaN    5503247814  550301001
# 11005                     NaN    1658052200  165801001
# 12500                     NaN    0326483040  032601001
#
#                Номер договора  Идентификатор номенклатуры  \
# 12401                     NaN                         NaN
# 12402                     NaN                         NaN
# 12403                     NaN                         NaN
# 16652  Подписка ПРО ЛК 155522                        40.0
# 16653  Подписка ПРО ЛК 155522                        40.0
# ...                       ...                         ...
# 9613                      NaN                         NaN
# 10037                     NaN                         NaN
# 10164                     NaN                         NaN
# 11005                     NaN                         NaN
# 12500                     NaN                         NaN
#
#       Название номенклатуры   Стоимость  Сумма  Начисления partner  \
# 12401                    NaN        0.0    0.0                 0.0
# 12402                    NaN        0.0    0.0                 0.0
# 12403                    NaN        0.0    0.0                 0.0
# 16652           Подписка ПРО        2.7    0.0                 0.0
# 16653           Подписка ПРО        2.7    0.0                 0.0
# ...                      ...        ...    ...                 ...
# 9613                     NaN        0.0    0.0                 0.0
# 10037                    NaN        0.0    0.0                 0.0
# 10164                    NaN        0.0    0.0                 0.0
# 11005                    NaN        0.0    0.0                 0.0
# 12500                    NaN        0.0    0.0                 0.0
#
#                   Тариф service  Сумма-test
# 12401             Start   start         0.0
# 12402             Start   start         0.0
# 12403               NaN   start         0.0
# 16652               NaN     pro         0.0
# 16653  PRO без биллинга     pro         0.0
# ...                 ...     ...         ...
# 9613                NaN   start         0.0
# 10037               NaN   start         0.0
# 10164               NaN   start         0.0
# 11005               NaN   start         0.0
# 12500               NaN   start         0.0
#
# [17710 rows x 15 columns]

# %%
for i in range(0,dataset.shape[0]):
    if i == 0:
        date = dataset.loc[0,'Дата']
        lk = dataset.loc[0,'Личный кабинет'] 
        dataset.loc[0,'ballance'] = 0
        dataset.loc[0,'ballance'] = dataset.loc[0,'Сумма'] - dataset.loc[0, 'Начисления partner']
        if dataset.loc[0,'ballance'] < 0:
            dataset.loc[0,'Сумма']  = 0
        if dataset.loc[0,'ballance'] >= 0:
                dataset.loc[0,'Сумма'] = dataset.loc[0,'ballance'] 
                dataset.loc[0,'ballance'] = 0
            
    else:
    
        if date == dataset.loc[i,'Дата'] and lk == dataset.loc[i,'Личный кабинет']:
            dataset.loc[i,'ballance'] = dataset.loc[i,'Сумма'] + dataset.loc[i-1,'ballance']
            if dataset.loc[i,'ballance'] < 0:
                dataset.loc[i,'Сумма']  = 0
                
            if dataset.loc[i,'ballance'] >= 0:
                dataset.loc[i,'Сумма'] = dataset.loc[i,'ballance']
                dataset.loc[i,'ballance'] = 0
        
        if date != dataset.loc[i,'Дата'] and lk == dataset.loc[i,'Личный кабинет']:  
            date = dataset.loc[i,'Дата']
            dataset.loc[i,'ballance'] = dataset.loc[i,'Сумма'] - dataset.loc[i, 'Начисления partner'] + dataset.loc[i-1,'ballance']
            if dataset.loc[i,'ballance'] < 0:
                dataset.loc[i,'Сумма']  = 0
                
            if dataset.loc[i,'ballance'] >= 0:
                dataset.loc[i,'Сумма'] = dataset.loc[i,'ballance']
                dataset.loc[i,'ballance'] = 0
        
        if lk != dataset.loc[i,'Личный кабинет']:  
            date = dataset.loc[i,'Дата']
            lk = dataset.loc[i,'Личный кабинет']
            
            dataset.loc[i,'ballance'] = dataset.loc[i,'Сумма'] \
                                        - dataset.loc[i, 'Начисления partner']
            if dataset.loc[i,'ballance'] < 0:
                dataset.loc[i,'Сумма']  = 0
                
            if dataset.loc[i,'ballance'] >= 0:
                dataset.loc[i,'Сумма'] = dataset.loc[i,'ballance']
                dataset.loc[i,'ballance'] = 0

# %%
dataset.to_excel('/home/boris/Downloads/'+ name + '_test.xlsx', index=False)

# %%
dataset_ready = dataset.drop(['Начисления partner','Сумма-test','ballance'], axis= 1)

# %%
dataset_ready['Количество'] = round(dataset_ready['Сумма']/dataset_ready['Стоимость'])
dataset_ready['Количество'] = dataset_ready['Количество'].fillna(0)

# %%
dataset_ready.to_excel('/home/boris/Downloads/'+ name + '_ready.xlsx', index=False)
