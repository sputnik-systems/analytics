# %%
import clickhouse_connect
import datetime
import os
import pytz
import pandas as pd
from dateutil.relativedelta import relativedelta
from dotenv import load_dotenv
import sys
import polars as pl
sys.path.append('/home/boris/Documents/Work/analytics/Clickhouse')
from clickhouse_client import ClickHouse_client
ch = ClickHouse_client()
pd.set_option('display.max_rows', 1000)
pl.Config.set_tbl_rows(1000)
# Out:
# polars.config.Config

# %% [markdown]
# ___
# ## Tags: #tools
# ___

# %%
query_text = """--sql
    SELECT view, status, next_refresh_time, exception, retry,progress, read_rows
    FROM system.view_refreshes
    ORDER BY next_refresh_time
"""
ch.query_run(query_text)
# Out:
# shape: (71, 7)
# ┌────────────────┬───────────┬────────────────┬────────────────┬───────┬──────────────┬────────────┐
# │ view           ┆ status    ┆ next_refresh_t ┆ exception      ┆ retry ┆ progress     ┆ read_rows  │
# │ ---            ┆ ---       ┆ ime            ┆ ---            ┆ ---   ┆ ---          ┆ ---        │
# │ str            ┆ str       ┆ ---            ┆ str            ┆ i64   ┆ f64          ┆ i64        │
# │                ┆           ┆ datetime[ns]   ┆                ┆       ┆              ┆            │
# ╞════════════════╪═══════════╪════════════════╪════════════════╪═══════╪══════════════╪════════════╡
# │ categories_st_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2211.0       ┆ 2211       │
# │ support_mv     ┆           ┆ 03:00:00       ┆                ┆       ┆              ┆            │
# │ requests_st_su ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 7149.0       ┆ 7149       │
# │ pport_mv       ┆           ┆ 03:00:00       ┆                ┆       ┆              ┆            │
# │ accruals_dir_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 11287.0      ┆ 11287      │
# │ artner_mv      ┆           ┆ 03:00:48       ┆                ┆       ┆              ┆            │
# │ metrics_all_in ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.0706931e7  ┆ 20706931   │
# │ tercoms_asgard ┆           ┆ 03:01:42       ┆                ┆       ┆              ┆            │
# │ _m…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ gates_st_partn ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 479380.0     ┆ 479380     │
# │ er_mv          ┆           ┆ 03:02:10       ┆                ┆       ┆              ┆            │
# │ cameras_daily_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 5.094887e6   ┆ 5094887    │
# │ percentage_onl ┆           ┆ 03:02:28       ┆                ┆       ┆              ┆            │
# │ in…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ hex_metrics_pa ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.76396463e8 ┆ 276396463  │
# │ rquet_asgard_m ┆           ┆ 03:02:54       ┆                ┆       ┆              ┆            │
# │ v              ┆           ┆                ┆                ┆       ┆              ┆            │
# │ citizen_paymen ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.120625e6   ┆ 2120625    │
# │ ts_st_mobile_m ┆           ┆ 03:03:18       ┆                ┆       ┆              ┆            │
# │ v              ┆           ┆                ┆                ┆       ┆              ┆            │
# │ metrics_asgard ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 324332.0     ┆ 324332     │
# │ _mv            ┆           ┆ 03:03:41       ┆                ┆       ┆              ┆            │
# │ cameras_dir_as ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 77781.0      ┆ 77781      │
# │ gard_mv        ┆           ┆ 03:04:08       ┆                ┆       ┆              ┆            │
# │ buildings_st_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 7.115542e6   ┆ 7115542    │
# │ artner_mv      ┆           ┆ 03:05:53       ┆                ┆       ┆              ┆            │
# │ billing_orders ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 490846.0     ┆ 490846     │
# │ _dir_partner_m ┆           ┆ 03:06:27       ┆                ┆       ┆              ┆            │
# │ v              ┆           ┆                ┆                ┆       ┆              ┆            │
# │ intercoms_dir_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 67181.0      ┆ 67181      │
# │ asgard_mv      ┆           ┆ 03:08:02       ┆                ┆       ┆              ┆            │
# │ reconnects_int ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 9.715542e6   ┆ 9715542    │
# │ ercoms_st_asga ┆           ┆ 03:08:58       ┆                ┆       ┆              ┆            │
# │ rd…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ companies_dir_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 36319.0      ┆ 36319      │
# │ partner_mv     ┆           ┆ 03:09:08       ┆                ┆       ┆              ┆            │
# │ cameras_st_asg ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 4.9442604e7  ┆ 49442604   │
# │ ard_mv         ┆           ┆ 03:09:39       ┆                ┆       ┆              ┆            │
# │ installation_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.3672499e7  ┆ 23672499   │
# │ oint_st_partne ┆           ┆ 03:09:51       ┆                ┆       ┆              ┆            │
# │ r_…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ no_video_on_st ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 3.571608e6   ┆ 3571608    │
# │ ream_mobile_st ┆           ┆ 03:10:12       ┆                ┆       ┆              ┆            │
# │ _a…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ cameras_dir_pa ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 45309.0      ┆ 45309      │
# │ rtner_mv       ┆           ┆ 03:10:27       ┆                ┆       ┆              ┆            │
# │ intercoms_dail ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.9055365e7  ┆ 19055365   │
# │ y_percentage_o ┆           ┆ 03:11:06       ┆                ┆       ┆              ┆            │
# │ nl…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ service_histor ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 95655.0      ┆ 95655      │
# │ y_dir_partner_ ┆           ┆ 03:11:21       ┆                ┆       ┆              ┆            │
# │ mv             ┆           ┆                ┆                ┆       ┆              ┆            │
# │ uk_st_partner_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 71619.0      ┆ 71619      │
# │ mv             ┆           ┆ 03:11:26       ┆                ┆       ┆              ┆            │
# │ citizens_dir_m ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.123111e6   ┆ 2123111    │
# │ obile_mv       ┆           ┆ 03:11:42       ┆                ┆       ┆              ┆            │
# │ citizen_paymen ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.202216e6   ┆ 2202216    │
# │ ts_dir_mobile_ ┆           ┆ 03:12:11       ┆                ┆       ┆              ┆            │
# │ mv             ┆           ┆                ┆                ┆       ┆              ┆            │
# │ uk_addresses_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 204.0        ┆ 204        │
# │ artner_mv      ┆           ┆ 03:13:09       ┆                ┆       ┆              ┆            │
# │ intercoms_dir_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 40820.0      ┆ 40820      │
# │ partner_mv     ┆           ┆ 03:14:08       ┆                ┆       ┆              ┆            │
# │ invites_dir_pa ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 7315.0       ┆ 7315       │
# │ rtner_mv       ┆           ┆ 03:15:24       ┆                ┆       ┆              ┆            │
# │ opendoor_types ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1120.0       ┆ 1120       │
# │ _mobile_st_asg ┆           ┆ 03:16:03       ┆                ┆       ┆              ┆            │
# │ ar…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ users_st_partn ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 7.613241e6   ┆ 7613241    │
# │ er_mv          ┆           ┆ 03:16:44       ┆                ┆       ┆              ┆            │
# │ flats_dir_part ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.002075e6   ┆ 1002075    │
# │ ner_mv         ┆           ┆ 03:17:39       ┆                ┆       ┆              ┆            │
# │ installation_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 115337.0     ┆ 115337     │
# │ oint_history_d ┆           ┆ 03:18:12       ┆                ┆       ┆              ┆            │
# │ ir…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ entries_st_mob ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.1866922e7  ┆ 21866922   │
# │ ile_mv         ┆           ┆ 03:18:19       ┆                ┆       ┆              ┆            │
# │ flats_st_partn ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 5.7445364e8  ┆ 574453640  │
# │ er_mv          ┆           ┆ 03:18:36       ┆                ┆       ┆              ┆            │
# │ subscriptions_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 6.0349609e7  ┆ 60349609   │
# │ st_mobile_mv   ┆           ┆ 03:19:34       ┆                ┆       ┆              ┆            │
# │ sessions_st_mo ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.74072294e8 ┆ 174072294  │
# │ bile_mv        ┆           ┆ 03:19:47       ┆                ┆       ┆              ┆            │
# │ uk_addresses_s ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 679372.0     ┆ 679372     │
# │ t_partner_mv   ┆           ┆ 03:20:40       ┆                ┆       ┆              ┆            │
# │ intercoms_st_a ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 4.4764614e7  ┆ 44764614   │
# │ sgard_mv       ┆           ┆ 03:20:54       ┆                ┆       ┆              ┆            │
# │ cameras_st_par ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.6290635e7  ┆ 26290635   │
# │ tner_mv        ┆           ┆ 03:21:22       ┆                ┆       ┆              ┆            │
# │ flussonic_stat ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.87907922e8 ┆ 187907922  │
# │ s_st_asgard_mv ┆           ┆ 03:22:30       ┆                ┆       ┆              ┆            │
# │ device_history ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 43578.0      ┆ 43578      │
# │ _dir_partner_m ┆           ┆ 03:24:07       ┆                ┆       ┆              ┆            │
# │ v              ┆           ┆                ┆                ┆       ┆              ┆            │
# │ intercoms_st_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 2.4088341e7  ┆ 24088341   │
# │ artner_mv      ┆           ┆ 03:26:50       ┆                ┆       ┆              ┆            │
# │ uk_dir_partner ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 192.0        ┆ 192        │
# │ _mv            ┆           ┆ 03:27:30       ┆                ┆       ┆              ┆            │
# │ entries_instal ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 39639.0      ┆ 39639      │
# │ lation_points_ ┆           ┆ 03:28:05       ┆                ┆       ┆              ┆            │
# │ di…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ all_installeti ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 8.799421e6   ┆ 8799421    │
# │ on_points_parq ┆           ┆ 04:00:00       ┆                ┆       ┆              ┆            │
# │ ue…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ rep_mobile_cit ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 1295530549 │
# │ izens_id_city_ ┆           ┆ 04:05:00       ┆                ┆       ┆              ┆            │
# │ pa…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_gropped_reco ┆ Scheduled ┆ 2025-08-16     ┆ Code: 241.     ┆ 3     ┆ 1.0          ┆ 123018333  │
# │ nnects_and_dai ┆           ┆ 04:05:00       ┆ DB::Exception: ┆       ┆              ┆            │
# │ ly…            ┆           ┆                ┆ (tot…          ┆       ┆              ┆            │
# │ total_active_u ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 0.212043     ┆ 236602358  │
# │ sers_per_day_f ┆           ┆ 04:10:00       ┆                ┆       ┆              ┆            │
# │ ul…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ complaints_st_ ┆ Scheduled ┆ 2025-08-16     ┆ Code: 27.      ┆ 3     ┆ 0.0          ┆ 0          │
# │ partner_mv     ┆           ┆ 04:18:19       ┆ DB::Exception: ┆       ┆              ┆            │
# │                ┆           ┆                ┆ Canno…         ┆       ┆              ┆            │
# │ companies_st_p ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 5.826028e6   ┆ 5826028    │
# │ artner_mv      ┆           ┆ 04:23:02       ┆                ┆       ┆              ┆            │
# │ billing_orders ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 9.691519e6   ┆ 9691519    │
# │ _devices_st_pa ┆           ┆ 04:27:03       ┆                ┆       ┆              ┆            │
# │ rt…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_count_of_nuw ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 1320749498 │
# │ _addresses_mv  ┆           ┆ 05:00:00       ┆                ┆       ┆              ┆            │
# │ t_device_histo ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.096928     ┆ 83232629   │
# │ ry_by_companys ┆           ┆ 05:05:00       ┆                ┆       ┆              ┆            │
# │ _a…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_device_and_s ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 49857547   │
# │ hipment_histor ┆           ┆ 05:10:00       ┆                ┆       ┆              ┆            │
# │ y_…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_cameras_by_c ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 55325855   │
# │ ompanies_mv    ┆           ┆ 05:15:00       ┆                ┆       ┆              ┆            │
# │ t_citizens_cou ┆ Scheduled ┆ 2025-08-16     ┆ Code: 390.     ┆ 3     ┆ 0.0          ┆ 0          │
# │ nt_in_flats_mv ┆           ┆ 05:23:00       ┆ DB::Exception: ┆       ┆              ┆            │
# │                ┆           ┆                ┆ Tabl…          ┆       ┆              ┆            │
# │ t_device_billi ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 50731760   │
# │ ns_mv          ┆           ┆ 05:25:00       ┆                ┆       ┆              ┆            │
# │ t_subscribtion ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.000062     ┆ 3989313325 │
# │ s_citizens_by_ ┆           ┆ 05:25:00       ┆                ┆       ┆              ┆            │
# │ co…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_subscribtion ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 4109404373 │
# │ s_citizens_by_ ┆           ┆ 05:27:00       ┆                ┆       ┆              ┆            │
# │ co…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ new_users_pd_r ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.000122     ┆ 5345308736 │
# │ ep_mobile_tota ┆           ┆ 05:30:00       ┆                ┆       ┆              ┆            │
# │ l_…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_billings_coh ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 53638421   │
# │ orts_mv        ┆           ┆ 05:30:00       ┆                ┆       ┆              ┆            │
# │ t_count_of_sub ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 1381214609 │
# │ scribes_by_adr ┆           ┆ 05:33:00       ┆                ┆       ┆              ┆            │
# │ es…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ t_requests_st_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 24200954   │
# │ support_mv     ┆           ┆ 05:35:00       ┆                ┆       ┆              ┆            │
# │ t_requests_inf ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 24200954   │
# │ o_st_support_m ┆           ┆ 05:35:00       ┆                ┆       ┆              ┆            │
# │ v              ┆           ┆                ┆                ┆       ┆              ┆            │
# │ mobile_report_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 882882945  │
# │ rep_mobile_ful ┆           ┆ 05:40:00       ┆                ┆       ┆              ┆            │
# │ l_…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ mobile_report_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 630210     │
# │ cum_rep_mobile ┆           ┆ 05:43:00       ┆                ┆       ┆              ┆            │
# │ _f…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ maf_rep_mobile ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 100        │
# │ _total_mv      ┆           ┆ 05:45:00       ┆                ┆       ┆              ┆            │
# │ total_activate ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.027238     ┆ 904752353  │
# │ d_account_rep_ ┆           ┆ 06:00:00       ┆                ┆       ┆              ┆            │
# │ mo…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ total_active_u ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 100        │
# │ sers_per_day_r ┆           ┆ 06:05:00       ┆                ┆       ┆              ┆            │
# │ ep…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ units_on_sk_pl ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 53602102   │
# │ atform_rep_mob ┆           ┆ 06:08:00       ┆                ┆       ┆              ┆            │
# │ il…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ total_active_u ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.0          ┆ 71970399   │
# │ sers_rep_mobil ┆           ┆ 06:08:00       ┆                ┆       ┆              ┆            │
# │ e_…            ┆           ┆                ┆                ┆       ┆              ┆            │
# │ mobile_report_ ┆ Scheduled ┆ 2025-08-16     ┆                ┆ 0     ┆ 1.00703      ┆ 52524711   │
# │ total_mv       ┆           ┆ 06:15:00       ┆                ┆       ┆              ┆            │
# └────────────────┴───────────┴────────────────┴────────────────┴───────┴──────────────┴────────────┘
