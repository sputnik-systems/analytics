# %%
import clickhouse_connect
import datetime
import os
import pytz
import pandas as pd
from dateutil.relativedelta import relativedelta
from dotenv import load_dotenv

from ClickHouse_client import ClickHouse_client
ch = ClickHouse_client()

# %% [markdown]
# ## Show all tables

# %%
query_text = """--sql
    SHOW TABLES FROM db1
"""
ch.query_run(query_text)
# Out:
#                                          name
# 0                        accruals_dir_partner
# 1                  all_order_accumulated_data
# 2                     all_order_google_sheets
# 3                  billing_orders_dir_partner
# 4                          cameras_dir_asgard
# 5                         cameras_dir_partner
# 6                           cameras_st_asgard
# 7                          cameras_st_partner
# 8                       cameras_st_partner_ch
# 9                       cameras_st_partner_mv
# 10                 cameras_st_partner_parquet
# 11                        citizens_dir_mobile
# 12                         citizens_st_mobile
# 13                    citizens_st_mobile_test
# 14                      companies_dir_partner
# 15                       companies_st_partner
# 16                           date_range_table
# 17                             device_history
# 18         device_history_by_company_and_city
# 19                 device_history_dir_partner
# 20              device_history_dir_partner_ch
# 21              device_history_dir_partner_mv
# 22    entries_installation_points_dir_partner
# 23     installation_point_history_dir_partner
# 24  installation_point_history_dir_partner_ch
# 25  installation_point_history_dir_partner_mv
# 26              installation_point_st_partner
# 27                       intercoms_dir_asgard
# 28                      intercoms_dir_partner
# 29                        intercoms_st_asgard
# 30                       intercoms_st_partner
# 31                        invites_dir_partner
# 32                     invites_dir_partner_ch
# 33                     invites_dir_partner_mv
# 34                    subscriptions_st_mobile
# 35                                      test1
# 36                       uk_addresses_partner
# 37                    uk_addresses_partner_ch
# 38                    uk_addresses_partner_mv
# 39                           users_st_partner
# 40                        users_st_partner_ch
# 41                        users_st_partner_mv

# %% [markdown]
# ## uk_addresses_partner

# %%
query_text = """--sql
    CREATE TABLE db1.uk_addresses_partner
    (
        `patrner_uuid_uk` String,
        `address_uuid`  String,
    )
    ENGINE = S3('https://storage.yandexcloud.net/dwh-asgard/uk_addresses_partner/uk_addresses_partner.csv','CSVWithNames')
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
    CREATE TABLE db1.uk_addresses_partner_ch
    (
        `patrner_uuid_uk` String,
        `address_uuid`  String,
    )
    ENGINE = MergeTree()
    ORDER BY patrner_uuid_uk
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
    CREATE MATERIALIZED VIEW db1.uk_addresses_partner_mv
    REFRESH EVERY 1 DAY OFFSET 3 HOUR RANDOMIZE FOR 1 HOUR TO db1.uk_addresses_partner_ch AS
    SELECT
        *
    FROM db1.uk_addresses_partner
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## users_st_partner

# %%
query_text = """--sql
    CREATE TABLE db1.users_st_partner
    (
        `report_date` Date,
        `partner_uuid`  String,
        `last_logging` DateTime
    )
    ENGINE = S3('https://storage.yandexcloud.net/dwh-asgard/users_st_partner/year=*/month=*/*.csv','CSVWithNames')
    """

ch.query_run(query_text)

# %%
query_text = """--sql
    CREATE TABLE db1.users_st_partner_ch
    (
        `report_date` Date,
        `partner_uuid`  String,
        `last_logging` DateTime
    )
    ENGINE = MergeTree()
    ORDER BY partner_uuid
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
    CREATE MATERIALIZED VIEW db1.users_st_partner_mv
    REFRESH EVERY 1 DAY OFFSET 3 HOUR RANDOMIZE FOR 1 HOUR TO db1.users_st_partner_ch AS
    SELECT
        *
    FROM db1.users_st_partner
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
   SELECT * FROM db1.users_st_partner_ch
   WHERE partner_uuid != ''
   LIMIT 10
    """

ch.query_run(query_text)
# Out:
#   report_date                          partner_uuid last_logging
# 0  2024-04-26  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 1  2024-04-22  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 2  2024-04-25  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 3  2024-04-23  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 4  2024-04-28  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 5  2024-04-29  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 6  2024-04-27  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 7  2024-04-30  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 8  2024-04-03  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01
# 9  2024-04-04  47c998d6-f57c-4c57-a7e9-c1279da45fe9   1970-01-01

# %% [markdown]
# ## uk_addresses_st_partner

# %%
query_text = """--sql
    CREATE TABLE db1.uk_addresses_st_partner
    (
        `report_date` Date,
        `partner_uuid_uk`  String,
        `address_uuid` String
    )
    ENGINE = S3('https://storage.yandexcloud.net/dwh-asgard/uk_addresses_st_partner/year=*/month=*/*.csv','CSVWithNames')
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
    CREATE TABLE db1.uk_addresses_st_partner_ch
    (
       `report_date` Date,
        `partner_uuid_uk` String,
        `address_uuid` String
    )
    ENGINE = MergeTree()
    ORDER BY partner_uuid_uk
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
    CREATE MATERIALIZED VIEW db1.uk_addresses_st_partner_mv
    REFRESH EVERY 1 DAY OFFSET 3 HOUR RANDOMIZE FOR 1 HOUR TO db1.uk_addresses_st_partner_ch AS
    SELECT
        *
    FROM db1.uk_addresses_st_partner
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = """--sql
   SELECT * FROM db1.uk_addresses_st_partner_ch
   WHERE partner_uuid_uk != ''
   LIMIT 10
    """

ch.query_run(query_text)
# Out:
#   report_date                       partner_uuid_uk  \
# 0  2024-10-01  0076e1b0-72c3-4783-9306-93d2990387ae
# 1  2024-10-01  0076e1b0-72c3-4783-9306-93d2990387ae
# 2  2024-10-10  0076e1b0-72c3-4783-9306-93d2990387ae
# 3  2024-10-10  0076e1b0-72c3-4783-9306-93d2990387ae
# 4  2024-10-11  0076e1b0-72c3-4783-9306-93d2990387ae
# 5  2024-10-11  0076e1b0-72c3-4783-9306-93d2990387ae
# 6  2024-10-12  0076e1b0-72c3-4783-9306-93d2990387ae
# 7  2024-10-12  0076e1b0-72c3-4783-9306-93d2990387ae
# 8  2024-10-15  0076e1b0-72c3-4783-9306-93d2990387ae
# 9  2024-10-15  0076e1b0-72c3-4783-9306-93d2990387ae
#
#                            address_uuid
# 0  cb0afec6-4041-4c9b-b9fd-9cd62a9ec6b0
# 1  acc6f2b2-98dc-4657-8f07-0c9b7a1018fb
# 2  cb0afec6-4041-4c9b-b9fd-9cd62a9ec6b0
# 3  acc6f2b2-98dc-4657-8f07-0c9b7a1018fb
# 4  cb0afec6-4041-4c9b-b9fd-9cd62a9ec6b0
# 5  acc6f2b2-98dc-4657-8f07-0c9b7a1018fb
# 6  cb0afec6-4041-4c9b-b9fd-9cd62a9ec6b0
# 7  acc6f2b2-98dc-4657-8f07-0c9b7a1018fb
# 8  cb0afec6-4041-4c9b-b9fd-9cd62a9ec6b0
# 9  acc6f2b2-98dc-4657-8f07-0c9b7a1018fb
