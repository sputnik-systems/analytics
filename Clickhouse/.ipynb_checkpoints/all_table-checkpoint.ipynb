# %%
import clickhouse_connect
import datetime
import os
import pytz
import pandas as pd
from dateutil.relativedelta import relativedelta
from dotenv import load_dotenv
import sys
sys.path.append('/home/boris/Documents/Work/analytics/Clickhouse')
from clickhouse_client import ClickHouse_client
ch = ClickHouse_client()
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ___
# ## Tags: #tools
# ___

# %%
query_text = """--sql
    SELECT view, status, next_refresh_time, exception, retry,progress, read_rows
    FROM system.view_refreshes
    ORDER BY next_refresh_time
"""
ch.query_run(query_text)
# Out:
#                                                  view     status  \
# 0                                flats_dir_partner_mv  Scheduled
# 1                                   metrics_asgard_mv  Scheduled
# 2                                cameras_st_asgard_mv  Scheduled
# 3                             buildings_st_partner_mv  Scheduled
# 4                       device_history_dir_partner_mv  Scheduled
# 5                              citizens_dir_mobile_mv  Scheduled
# 6                               cameras_st_partner_mv  Scheduled
# 7                             accruals_dir_partner_mv  Scheduled
# 8                   reconnects_intercoms_st_asgard_mv  Scheduled
# 9                             intercoms_st_partner_mv  Scheduled
# 10                              citizens_st_mobile_mv  Scheduled
# 11       cameras_daily_percentage_online_st_asgard_mv  Scheduled
# 12     intercoms_daily_percentage_online_st_asgard_mv  Scheduled
# 13                     citizen_payments_dir_mobile_mv  Scheduled
# 14                             cameras_dir_partner_mv  Scheduled
# 15                           intercoms_dir_partner_mv  Scheduled
# 16                      hex_metrics_parquet_asgard_mv  Scheduled
# 17                               entries_st_mobile_mv  Scheduled
# 18                                flats_st_partner_mv  Scheduled
# 19                              sessions_st_mobile_mv  Scheduled
# 20                    citizens_st_mobile_test_uuid_mv  Scheduled
# 21                                users_st_partner_mv  Scheduled
# 22                              cameras_dir_asgard_mv  Scheduled
# 23                         uk_addresses_st_partner_mv  Scheduled
# 24                                  uk_dir_partner_mv  Scheduled
# 25                   installation_point_st_partner_mv  Scheduled
# 26                            uk_addresses_partner_mv  Scheduled
# 27                                gates_st_partner_mv  Scheduled
# 28                             invites_dir_partner_mv  Scheduled
# 29                     service_history_dir_partner_mv  Scheduled
# 30                 opendoor_types_mobile_st_asgard_mv  Scheduled
# 31                         subscriptions_st_mobile_mv  Scheduled
# 32          installation_point_history_dir_partner_mv  Scheduled
# 33                             intercoms_st_asgard_mv  Scheduled
# 34         entries_installation_points_dir_partner_mv  Scheduled
# 35                           companies_dir_partner_mv  Scheduled
# 36                            intercoms_dir_asgard_mv  Scheduled
# 37                      billing_orders_dir_partner_mv  Scheduled
# 38                                   uk_st_partner_mv  Scheduled
# 39             no_video_on_stream_mobile_st_asgard_mv  Scheduled
# 40                    metrics_all_intercoms_asgard_mv  Scheduled
# 41                      citizen_payments_st_mobile_mv  Scheduled
# 42                       flussonic_stats_st_asgard_mv  Scheduled
# 43                      citizens_st_mobile_parquet_mv  Scheduled
# 44                 all_installetion_points_parquet_mv  Scheduled
# 45               billing_orders_devices_st_partner_mv  Scheduled
# 46                            companies_st_partner_mv  Scheduled
# 47                        t_count_of_nuw_addresses_mv  Scheduled
# 48          t_device_history_by_companys_and_citys_mv  Scheduled
# 49  t_device_and_shipment_history_by_company_and_c...  Scheduled
# 50                          t_cameras_by_companies_mv  Scheduled
# 51                       t_citizens_count_in_flats_mv  Scheduled
# 52                                t_device_billins_mv  Scheduled
# 53  t_subscribtions_citizens_by_companies_and_citi...  Scheduled
# 54  t_subscribtions_citizens_by_companies_and_citi...  Scheduled
#
#      next_refresh_time                                          exception  \
# 0  2025-07-08 03:00:52
# 1  2025-07-08 03:01:09
# 2  2025-07-08 03:01:21
# 3  2025-07-08 03:02:11
# 4  2025-07-08 03:03:52
# 5  2025-07-08 03:07:32
# 6  2025-07-08 03:08:32
# 7  2025-07-08 03:08:34
