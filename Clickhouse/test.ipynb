# %%
import clickhouse_connect
import datetime
import os
import pytz
import pandas as pd
from dateutil.relativedelta import relativedelta
from dotenv import load_dotenv

from ClickHouse_client import ClickHouse_client
ch = ClickHouse_client()

# %%
query_text = """--sql
SELECT
    *
FROM db1.cameras_st_partner_ch
ORDER BY report_date desc
limit 10
"""

ch.query_run(query_text)
# Out:
#   report_date                  service_partner_uuid  \
# 0  2025-05-28  5cc8bbed-4115-4f00-891c-a72710e4dc22
# 1  2025-05-28  2c6bc0f4-cac7-4ac6-98c9-a5f3041f027e
# 2  2025-05-28
# 3  2025-05-28  495b2f5e-8835-49a3-9c20-3571a8003adb
# 4  2025-05-28  b3e8988d-7c75-45b7-bc56-3818518de9d0
# 5  2025-05-28  fcf08f1c-65aa-484f-9525-54b783b64177
# 6  2025-05-28  1c64b848-e82c-46ee-9d0d-c740938408d4
# 7  2025-05-28  adeffb47-1707-4976-a4a6-e6eacf19b050
# 8  2025-05-28  23dcf97a-72de-4709-aeb0-e62082ef5d18
# 9  2025-05-28  c259e6bf-517a-4f87-ba0c-99c7ea8e7f44
#
#                            partner_uuid                         intercom_uuid  \
# 0  0e7236ac-b8bd-4ab0-8634-d165ad17190e  3034935a-32b3-4994-b7f4-ab268a692964
# 1  2c6bc0f4-cac7-4ac6-98c9-a5f3041f027e  fe20bdfd-3b9d-44a2-832f-1ac6284f8b6e
# 2  6818fe8d-8f5e-4f93-a5d6-8e7ebd83dcd5
# 3  0e7236ac-b8bd-4ab0-8634-d165ad17190e  7970a1fd-26c7-4cb9-ad2a-e95b2b80d565
# ...

# %%
query_text
# Out:
# "--sql\n    CREATE TABLE db1.uk_addresses_partner\n    (\n        `patrner_uuid_uk` String,\n        `address_uuid`  String,\n    )\n    ENGINE = S3('https://storage.yandexcloud.net/dwh-asgard/uk_addresses_partner/uk_addresses_partner.csv','CSVWithNames');\n"

# %%
query_text = """--sql
    CREATE TABLE db1.uk_addresses_partner
    (
        `patrner_uuid_uk` String,
        `address_uuid`  String,
    )
    ENGINE = S3('https://storage.yandexcloud.net/dwh-asgard/uk_addresses_partner/uk_addresses_partner.csv','CSVWithNames')
    """

ch.query_run(query_text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
query_text = open('query.txt','r').read().format(yesterday_data,path,path_without_0,key)
result = client.query(query_text)

# %%
result = client.query(query_text)
df = pd.DataFrame(result.result_rows, columns=result.column_names)
df
# Out:
#   report_date                  service_partner_uuid  \
# 0  2025-05-28  5cc8bbed-4115-4f00-891c-a72710e4dc22
# 1  2025-05-28  2c6bc0f4-cac7-4ac6-98c9-a5f3041f027e
# 2  2025-05-28
# 3  2025-05-28  495b2f5e-8835-49a3-9c20-3571a8003adb
# 4  2025-05-28  b3e8988d-7c75-45b7-bc56-3818518de9d0
# 5  2025-05-28  fcf08f1c-65aa-484f-9525-54b783b64177
# 6  2025-05-28  1c64b848-e82c-46ee-9d0d-c740938408d4
# 7  2025-05-28  adeffb47-1707-4976-a4a6-e6eacf19b050
# 8  2025-05-28  23dcf97a-72de-4709-aeb0-e62082ef5d18
# 9  2025-05-28  c259e6bf-517a-4f87-ba0c-99c7ea8e7f44
#
#                            partner_uuid                         intercom_uuid  \
# 0  0e7236ac-b8bd-4ab0-8634-d165ad17190e  3034935a-32b3-4994-b7f4-ab268a692964
# 1  2c6bc0f4-cac7-4ac6-98c9-a5f3041f027e  fe20bdfd-3b9d-44a2-832f-1ac6284f8b6e
# 2  6818fe8d-8f5e-4f93-a5d6-8e7ebd83dcd5
# 3  0e7236ac-b8bd-4ab0-8634-d165ad17190e  7970a1fd-26c7-4cb9-ad2a-e95b2b80d565
# ...

# %%
CREATE TABLE db1.uk_addresses_partner.csv
(
    `patrner_uuid_uk` String,
    `address_uuid`  String,
)
ENGINE = S3('https://storage.yandexcloud.net/dwh-asgard/uk_addresses_partner.csv/uk_addresses_partner.csv.csv',
 'CSVWithNames');
